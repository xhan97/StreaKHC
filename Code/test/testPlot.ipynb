# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
#wine
fig = plt.figure() 
ax1 = plt.axes(projection = '3d')
xd = [3,3,3,3,3,5,5,5,5,5,7,7,7,7,7,13,13,13,13,13,15,15,15,15,15]
yd = [0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1]
zd = [0.87,0.78,0.84,0.69,0.38,0.87,0.85,0.82,0.77,0.36,0.88,0.89,0.87,0.75,0.39,0.86,0.90,0.91,0.86,0.37,0.88,0.86,0.95,0.87,0.39]   
 
ax1.scatter3D(xd,yd,zd,color = 'blue',marker='^')
ax1.set_xlabel('psi')
ax1.set_ylabel('beta')
ax1.set_zlabel('purity')
plt.show()

# %%
#thyroid
fig = plt.figure() 
ax1 = plt.axes(projection = '3d')
xd = [3,3,3,3,3,5,5,5,5,5,7,7,7,7,7,13,13,13,13,13,15,15,15,15,15]
yd = [0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1]
zd = [0.79,0.76,0.57,0.53,0.55,0.78,0.80,0.65,0.54,0.54,0.81,0.77,0.73,0.64,0.55,0.76,0.80,0.75,0.74,0.55,0.78,0.78,0.83,0.74,0.53,]   
 
ax1.scatter3D(xd,yd,zd,color = 'red',marker='^')
ax1.set_xlabel('psi')
ax1.set_ylabel('beta')
ax1.set_zlabel('purity')
plt.show()

# %%
# lung
fig = plt.figure() 
ax1 = plt.axes(projection = '3d')
xd = [3,3,3,3,3,5,5,5,5,5,7,7,7,7,7,13,13,13,13,13,15,15,15,15,15]
yd = [0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1]
zd = [0.77,0.64,0.59,0.60,0.50,0.77,0.79,0.75,0.58,0.50,0.81,0.78,0.77,0.57,0.50,0.80,0.79,0.78,0.69,0.48,0.78,0.79,0.78,0.76,0.60]   
 
ax1.scatter3D(xd,yd,zd,color = 'red',marker='^')
ax1.set_xlabel('psi')
ax1.set_ylabel('beta')
ax1.set_zlabel('purity')
plt.show()

# %%
# WDBC
fig = plt.figure() 
ax1 = plt.axes(projection = '3d')
xd = [3,3,3,3,3,5,5,5,5,5,7,7,7,7,7,13,13,13,13,13,15,15,15,15,15]
yd = [0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1]
zd = [0.89,0.90,0.66,0.55,0.54,0.90,0.88,0.84,0.59,0.55,0.88,0.88,0.88,0.73,0.54,0.84,0.84,0.85,0.78,0.54,0.84,0.84,0.83,0.80,0.53,]   
 
ax1.scatter3D(xd,yd,zd,color = 'red',marker='^')
ax1.set_xlabel('psi')
ax1.set_ylabel('beta')
ax1.set_zlabel('purity')
plt.show()

# %%
# ALLAML
fig = plt.figure() 
ax1 = plt.axes(projection = '3d')
xd = [3,3,3,3,3,5,5,5,5,5,7,7,7,7,7,13,13,13,13,13,15,15,15,15,15]
yd = [0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1]
zd = [0.66,0.74,0.58,0.62,0.58,0.64,0.67,0.69,0.63,0.53,0.61,0.59,0.61,0.59,0.57,0.62,0.61,0.58,0.57,0.56,0.59,0.60,0.59,0.63,0.53]   
 
ax1.scatter3D(xd,yd,zd,color = 'red',marker='^')
ax1.set_xlabel('psi')
ax1.set_ylabel('beta')
ax1.set_zlabel('purity')
plt.show()

# %%
# LandCover
fig = plt.figure() 
ax1 = plt.axes(projection = '3d')
xd = [3,3,3,3,3,5,5,5,5,5,7,7,7,7,7,13,13,13,13,13,15,15,15,15,15]
yd = [0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1]
zd = [0.47,0.32,0.29,0.24,0.14,0.54,0.41,0.32,0.26,0.14,0.56,0.46,0.39,0.29,0.14,0.52,0.53,0.49,0.31,0.14,0.50,0.53,0.49,0.39,0.14]   
 
ax1.scatter3D(xd,yd,zd,color = 'red',marker='^')
ax1.set_xlabel('psi')
ax1.set_ylabel('beta')
ax1.set_zlabel('purity')
plt.show()

# %%
# Seeds
fig = plt.figure() 
ax1 = plt.axes(projection = '3d')
xd = [3,3,3,3,3,5,5,5,5,5,7,7,7,7,7,13,13,13,13,13,15,15,15,15,15]
yd = [0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1,0.6,0.7,0.8,0.9,1]
zd = [0.83,0.73,0.71,0.75,0.40,0.82,0.81,0.71,0.66,0.36,0.82,0.84,0.86,0.72,0.36,0.87,0.82,0.83,0.83,0.40,0.84,0.88,0.81,0.81,0.37]   
 
ax1.scatter3D(xd,yd,zd,color = 'red',marker='^')
ax1.set_xlabel('psi')
ax1.set_ylabel('beta')
ax1.set_zlabel('purity')
plt.show()
